# %%
from sqlalchemy.orm import declarative_base

from pydantic import BaseModel, ConfigDict, Field

# %%
from sqlalchemy import create_engine
engine = create_engine("postgresql+psycopg://AtvarsViola:AtvarsViola@127.0.0.1:5432/TaleMachine")

# %%
with engine.connect() as connection:
    pass #If this doesn't hang - success!

# %%
Base = declarative_base()

# %%
from sqlalchemy import Column, Integer, String, Text

# %%
class MessageBase(BaseModel):
    id: int
    role: str
    content: str
    session_id: int
    timestamp: int

# %%
class Message(MessageBase):
    model_config = ConfigDict(from_attributes=True)
    session: Session

# %%
class MessagesTable(Base): # Messages table for both user and AI messages
    __tablename__ = 'messages'
    id = Column(Integer, primary_key=True, index=True, autoincrement=True)
    # title = Column(String, index=True) # No title here, as it's applicable for a session can be changed by user
    content = Column(Text)
    role = Column(String)  # 'user' or 'ai'
    timestamp = Column(Integer)  # Unix timestamp
    session_id = Column(Integer, index=True)  # Foreign key to sessions table
